# %% [markdown]
# <a href="https://colab.research.google.com/github/Arbaj-Wadagera/AI_LAB-2024-25/blob/main/1BM22CS051__Hill_Climbing_algo__for_4_and_8_Queens.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
N = 4

def calculateCost(state):
    attacking_pairs = 0
    for i in range(N):
        for j in range(i + 1, N):
            if state[i] == state[j] or abs(state[i] - state[j]) == abs(i - j):
                attacking_pairs += 1
    return attacking_pairs

def getNeighbours(state):
    neighbours = []
    for i in range(N):
        for j in range(i + 1, N):
            new_state = state[:]
            new_state[i], new_state[j] = new_state[j], new_state[i]
            neighbours.append(new_state)
    return neighbours

def hillClimbing(initial_state):
    current_state = initial_state
    current_cost = calculateCost(current_state)

    iteration = 0
    while True:
        print(f"\nIteration {iteration}")
        print(f"Current State: {current_state}, Cost: {current_cost}")

        neighbours = getNeighbours(current_state)
        next_state = current_state
        next_cost = current_cost

        for neighbour in neighbours:
            cost = calculateCost(neighbour)
            print(f"Neighbour: {neighbour}, Cost: {cost}")
            if cost < next_cost:
                next_state = neighbour
                next_cost = cost

        if next_cost == current_cost:
            break
        else:
            current_state, current_cost = next_state, next_cost

        if current_cost == 0:
            break

        iteration += 1

    return current_state, current_cost

try:
    input_state = input("Enter initial state as 4 comma-separated integers (0 to 3): ")
    initial_state = list(map(int, input_state.split(',')))

    if len(initial_state) != N or any(not (0 <= x < N) for x in initial_state):
        raise ValueError("Invalid input. Please enter exactly 4 integers between 0 and 3.")

    solution_state, solution_cost = hillClimbing(initial_state)

    print("\nFinal Results")
    print("Initial State:", initial_state)
    print("Final State (Solution):", solution_state)
    print("Final Cost (Attacking Pairs):", solution_cost)

    if solution_cost == 0:
        print("Solution found!")
    else:
        print("Local optimum reached, but no solution.")
except ValueError as e:
    print(e)
# Out:
# Enter initial state as 4 comma-separated integers (0 to 3): 3,1,2,0
#
# Iteration 0
# Current State: [3, 1, 2, 0], Cost: 2
# Neighbour: [1, 3, 2, 0], Cost: 1
# Neighbour: [2, 1, 3, 0], Cost: 1
# Neighbour: [0, 1, 2, 3], Cost: 6
# Neighbour: [3, 2, 1, 0], Cost: 6
# Neighbour: [3, 0, 2, 1], Cost: 1
# Neighbour: [3, 1, 0, 2], Cost: 1
#
# Iteration 1
# Current State: [1, 3, 2, 0], Cost: 1
# Neighbour: [3, 1, 2, 0], Cost: 2
# Neighbour: [2, 3, 1, 0], Cost: 2
# Neighbour: [0, 3, 2, 1], Cost: 4
# Neighbour: [1, 2, 3, 0], Cost: 4
# Neighbour: [1, 0, 2, 3], Cost: 2
# Neighbour: [1, 3, 0, 2], Cost: 0
#
# Final Results
# Initial State: [3, 1, 2, 0]
# Final State (Solution): [1, 3, 0, 2]
# Final Cost (Attacking Pairs): 0
# Solution found!

# %%
N = 4

def calculateCost(state):
    attacking_pairs = 0
    for i in range(N):
        for j in range(i + 1, N):
            if state[i] == state[j] or abs(state[i] - state[j]) == abs(i - j):
                attacking_pairs += 1
    return attacking_pairs

def getNeighbours(state):
    neighbours = []
    for i in range(N):
        for j in range(i + 1, N):
            new_state = state[:]
            new_state[i], new_state[j] = new_state[j], new_state[i]
            neighbours.append(new_state)
    return neighbours

def hillClimbing(initial_state):
    current_state = initial_state
    current_cost = calculateCost(current_state)

    iteration = 0
    while True:
        print(f"\nIteration {iteration}")
        print(f"Current State: {current_state}, Cost: {current_cost}")

        neighbours = getNeighbours(current_state)
        next_state = current_state
        next_cost = current_cost

        for neighbour in neighbours:
            cost = calculateCost(neighbour)
            print(f"Neighbour: {neighbour}, Cost: {cost}")
            if cost < next_cost:
                next_state = neighbour
                next_cost = cost

        if next_cost == current_cost:
            break
        else:
            current_state, current_cost = next_state, next_cost

        if current_cost == 0:
            break

        iteration += 1

    return current_state, current_cost

try:
    input_state = input("Enter initial state as 4 comma-separated integers (0 to 3): ")
    initial_state = list(map(int, input_state.split(',')))

    if len(initial_state) != N or any(not (0 <= x < N) for x in initial_state):
        raise ValueError("Invalid input. Please enter exactly 4 integers between 0 and 3.")

    solution_state, solution_cost = hillClimbing(initial_state)

    print("\nFinal Results")
    print("Initial State:", initial_state)
    print("Final State (Solution):", solution_state)
    print("Final Cost (Attacking Pairs):", solution_cost)

    if solution_cost == 0:
        print("Solution found!")
    else:
        print("Local optimum reached, but no solution.")
except ValueError as e:
    print(e)
# Out:
# Enter initial state as 4 comma-separated integers (0 to 3): 3,2,1,0
#
# Iteration 0
# Current State: [3, 2, 1, 0], Cost: 6
# Neighbour: [2, 3, 1, 0], Cost: 2
# Neighbour: [1, 2, 3, 0], Cost: 4
# Neighbour: [0, 2, 1, 3], Cost: 2
# Neighbour: [3, 1, 2, 0], Cost: 2
# Neighbour: [3, 0, 1, 2], Cost: 4
# Neighbour: [3, 2, 0, 1], Cost: 2
#
# Iteration 1
# Current State: [2, 3, 1, 0], Cost: 2
# Neighbour: [3, 2, 1, 0], Cost: 6
# Neighbour: [1, 3, 2, 0], Cost: 1
# Neighbour: [0, 3, 1, 2], Cost: 1
# Neighbour: [2, 1, 3, 0], Cost: 1
# Neighbour: [2, 0, 1, 3], Cost: 1
# Neighbour: [2, 3, 0, 1], Cost: 4
#
# Iteration 2
# Current State: [1, 3, 2, 0], Cost: 1
# Neighbour: [3, 1, 2, 0], Cost: 2
# Neighbour: [2, 3, 1, 0], Cost: 2
# Neighbour: [0, 3, 2, 1], Cost: 4
# Neighbour: [1, 2, 3, 0], Cost: 4
# Neighbour: [1, 0, 2, 3], Cost: 2
# Neighbour: [1, 3, 0, 2], Cost: 0
#
# Final Results
# Initial State: [3, 2, 1, 0]
# Final State (Solution): [1, 3, 0, 2]
# Final Cost (Attacking Pairs): 0
# Solution found!

# %%
N = 8

def calculateCost(state):
    attacking_pairs = 0
    for i in range(N):
        for j in range(i + 1, N):
            if state[i] == state[j] or abs(state[i] - state[j]) == abs(i - j):
                attacking_pairs += 1
    return attacking_pairs

def getNeighbours(state):
    neighbours = []
    for i in range(N):
        for j in range(i + 1, N):
            new_state = state[:]
            new_state[i], new_state[j] = new_state[j], new_state[i]
            neighbours.append(new_state)
    return neighbours

def hillClimbing(initial_state):
    current_state = initial_state
    current_cost = calculateCost(current_state)

    iteration = 0
    while True:
        print(f"\nIteration {iteration}")
        print(f"Current State: {current_state}, Cost: {current_cost}")

        neighbours = getNeighbours(current_state)
        next_state = current_state
        next_cost = current_cost

        for neighbour in neighbours:
            cost = calculateCost(neighbour)
            print(f"Neighbour: {neighbour}, Cost: {cost}")
            if cost < next_cost:
                next_state = neighbour
                next_cost = cost

        if next_cost == current_cost:
            break
        else:
            current_state, current_cost = next_state, next_cost

        if current_cost == 0:
            break

        iteration += 1

    return current_state, current_cost

try:
    input_state = input("Enter initial state as 8 comma-separated integers (0 to 7): ")
    initial_state = list(map(int, input_state.split(',')))

    if len(initial_state) != N or any(not (0 <= x < N) for x in initial_state):
        raise ValueError("Invalid input. Please enter exactly 8 integers between 0 and 7.")

    solution_state, solution_cost = hillClimbing(initial_state)

    print("\nFinal Results")
    print("Initial State:", initial_state)
    print("Final State (Solution):", solution_state)
    print("Final Cost (Attacking Pairs):", solution_cost)

    if solution_cost == 0:
        print("Solution found!")
    else:
        print("Local optimum reached, but no solution.")
except ValueError as e:
    print(e)
# Out:
# Enter initial state as 8 comma-separated integers (0 to 7): 0,4,7,5,2,6,1,3
#
# Iteration 0
# Current State: [0, 4, 7, 5, 2, 6, 1, 3], Cost: 0
# Neighbour: [4, 0, 7, 5, 2, 6, 1, 3], Cost: 0
# Neighbour: [7, 4, 0, 5, 2, 6, 1, 3], Cost: 2
# Neighbour: [5, 4, 7, 0, 2, 6, 1, 3], Cost: 2
# Neighbour: [2, 4, 7, 5, 0, 6, 1, 3], Cost: 2
# Neighbour: [6, 4, 7, 5, 2, 0, 1, 3], Cost: 3
# Neighbour: [1, 4, 7, 5, 2, 6, 0, 3], Cost: 2
# Neighbour: [3, 4, 7, 5, 2, 6, 1, 0], Cost: 2
# Neighbour: [0, 7, 4, 5, 2, 6, 1, 3], Cost: 3
# Neighbour: [0, 5, 7, 4, 2, 6, 1, 3], Cost: 3
# Neighbour: [0, 2, 7, 5, 4, 6, 1, 3], Cost: 3
# Neighbour: [0, 6, 7, 5, 2, 4, 1, 3], Cost: 3
# Neighbour: [0, 1, 7, 5, 2, 6, 4, 3], Cost: 3
# Neighbour: [0, 3, 7, 5, 2, 6, 1, 4], Cost: 2
# Neighbour: [0, 4, 5, 7, 2, 6, 1, 3], Cost: 3
# Neighbour: [0, 4, 2, 5, 7, 6, 1, 3], Cost: 3
# Neighbour: [0, 4, 6, 5, 2, 7, 1, 3], Cost: 2
# Neighbour: [0, 4, 1, 5, 2, 6, 7, 3], Cost: 1
# Neighbour: [0, 4, 3, 5, 2, 6, 1, 7], Cost: 3
# Neighbour: [0, 4, 7, 2, 5, 6, 1, 3], Cost: 3
# Neighbour: [0, 4, 7, 6, 2, 5, 1, 3], Cost: 4
# Neighbour: [0, 4, 7, 1, 2, 6, 5, 3], Cost: 2
# Neighbour: [0, 4, 7, 3, 2, 6, 1, 5], Cost: 3
# Neighbour: [0, 4, 7, 5, 6, 2, 1, 3], Cost: 3
# Neighbour: [0, 4, 7, 5, 1, 6, 2, 3], Cost: 3
# Neighbour: [0, 4, 7, 5, 3, 6, 1, 2], Cost: 3
# Neighbour: [0, 4, 7, 5, 2, 1, 6, 3], Cost: 3
# Neighbour: [0, 4, 7, 5, 2, 3, 1, 6], Cost: 2
# Neighbour: [0, 4, 7, 5, 2, 6, 3, 1], Cost: 2
#
# Final Results
# Initial State: [0, 4, 7, 5, 2, 6, 1, 3]
# Final State (Solution): [0, 4, 7, 5, 2, 6, 1, 3]
# Final Cost (Attacking Pairs): 0
# Solution found!

# %%
N = 8

def calculateCost(state):
    attacking_pairs = 0
    for i in range(N):
        for j in range(i + 1, N):
            if state[i] == state[j] or abs(state[i] - state[j]) == abs(i - j):
                attacking_pairs += 1
    return attacking_pairs

def getNeighbours(state):
    neighbours = []
    for i in range(N):
        for j in range(i + 1, N):
            new_state = state[:]
            new_state[i], new_state[j] = new_state[j], new_state[i]
            neighbours.append(new_state)
    return neighbours

def hillClimbing(initial_state):
    current_state = initial_state
    current_cost = calculateCost(current_state)

    iteration = 0
    while True:
        print(f"\nIteration {iteration}")
        print(f"Current State: {current_state}, Cost: {current_cost}")

        neighbours = getNeighbours(current_state)
        next_state = current_state
        next_cost = current_cost

        for neighbour in neighbours:
            cost = calculateCost(neighbour)
            print(f"Neighbour: {neighbour}, Cost: {cost}")
            if cost < next_cost:
                next_state = neighbour
                next_cost = cost

        if next_cost == current_cost:
            break
        else:
            current_state, current_cost = next_state, next_cost

        if current_cost == 0:
            break

        iteration += 1

    return current_state, current_cost

try:
    input_state = input("Enter initial state as 8 comma-separated integers (0 to 7): ")
    initial_state = list(map(int, input_state.split(',')))

    if len(initial_state) != N or any(not (0 <= x < N) for x in initial_state):
        raise ValueError("Invalid input. Please enter exactly 8 integers between 0 and 7.")

    solution_state, solution_cost = hillClimbing(initial_state)

    print("\nFinal Results")
    print("Initial State:", initial_state)
    print("Final State (Solution):", solution_state)
    print("Final Cost (Attacking Pairs):", solution_cost)

    if solution_cost == 0:
        print("Solution found!")
    else:
        print("Local optimum reached, but no solution.")
except ValueError as e:
    print(e)
# Out:
# Enter initial state as 8 comma-separated integers (0 to 7): 0,4,7,5,2,3,6,1
#
# Iteration 0
# Current State: [0, 4, 7, 5, 2, 3, 6, 1], Cost: 5
# Neighbour: [4, 0, 7, 5, 2, 3, 6, 1], Cost: 4
# Neighbour: [7, 4, 0, 5, 2, 3, 6, 1], Cost: 6
# Neighbour: [5, 4, 7, 0, 2, 3, 6, 1], Cost: 4
# Neighbour: [2, 4, 7, 5, 0, 3, 6, 1], Cost: 4
# Neighbour: [3, 4, 7, 5, 2, 0, 6, 1], Cost: 3
# Neighbour: [6, 4, 7, 5, 2, 3, 0, 1], Cost: 8
# Neighbour: [1, 4, 7, 5, 2, 3, 6, 0], Cost: 2
# Neighbour: [0, 7, 4, 5, 2, 3, 6, 1], Cost: 10
# Neighbour: [0, 5, 7, 4, 2, 3, 6, 1], Cost: 4
# Neighbour: [0, 2, 7, 5, 4, 3, 6, 1], Cost: 9
# Neighbour: [0, 3, 7, 5, 2, 4, 6, 1], Cost: 4
# Neighbour: [0, 6, 7, 5, 2, 3, 4, 1], Cost: 7
# Neighbour: [0, 1, 7, 5, 2, 3, 6, 4], Cost: 5
# Neighbour: [0, 4, 5, 7, 2, 3, 6, 1], Cost: 4
# Neighbour: [0, 4, 2, 5, 7, 3, 6, 1], Cost: 7
# Neighbour: [0, 4, 3, 5, 2, 7, 6, 1], Cost: 5
# Neighbour: [0, 4, 6, 5, 2, 3, 7, 1], Cost: 7
# Neighbour: [0, 4, 1, 5, 2, 3, 6, 7], Cost: 5
# Neighbour: [0, 4, 7, 2, 5, 3, 6, 1], Cost: 4
# Neighbour: [0, 4, 7, 3, 2, 5, 6, 1], Cost: 7
# Neighbour: [0, 4, 7, 6, 2, 3, 5, 1], Cost: 4
# Neighbour: [0, 4, 7, 1, 2, 3, 6, 5], Cost: 8
# Neighbour: [0, 4, 7, 5, 3, 2, 6, 1], Cost: 3
# Neighbour: [0, 4, 7, 5, 6, 3, 2, 1], Cost: 7
# Neighbour: [0, 4, 7, 5, 1, 3, 6, 2], Cost: 4
# Neighbour: [0, 4, 7, 5, 2, 6, 3, 1], Cost: 2
# Neighbour: [0, 4, 7, 5, 2, 1, 6, 3], Cost: 3
# Neighbour: [0, 4, 7, 5, 2, 3, 1, 6], Cost: 2
#
# Iteration 1
# Current State: [1, 4, 7, 5, 2, 3, 6, 0], Cost: 2
# Neighbour: [4, 1, 7, 5, 2, 3, 6, 0], Cost: 3
# Neighbour: [7, 4, 1, 5, 2, 3, 6, 0], Cost: 3
# Neighbour: [5, 4, 7, 1, 2, 3, 6, 0], Cost: 5
# Neighbour: [2, 4, 7, 5, 1, 3, 6, 0], Cost: 3
# Neighbour: [3, 4, 7, 5, 2, 1, 6, 0], Cost: 2
# Neighbour: [6, 4, 7, 5, 2, 3, 1, 0], Cost: 4
# Neighbour: [0, 4, 7, 5, 2, 3, 6, 1], Cost: 5
# Neighbour: [1, 7, 4, 5, 2, 3, 6, 0], Cost: 6
# Neighbour: [1, 5, 7, 4, 2, 3, 6, 0], Cost: 4
# Neighbour: [1, 2, 7, 5, 4, 3, 6, 0], Cost: 5
# Neighbour: [1, 3, 7, 5, 2, 4, 6, 0], Cost: 2
# Neighbour: [1, 6, 7, 5, 2, 3, 4, 0], Cost: 6
# Neighbour: [1, 0, 7, 5, 2, 3, 6, 4], Cost: 3
# Neighbour: [1, 4, 5, 7, 2, 3, 6, 0], Cost: 3
# Neighbour: [1, 4, 2, 5, 7, 3, 6, 0], Cost: 3
# Neighbour: [1, 4, 3, 5, 2, 7, 6, 0], Cost: 4
# Neighbour: [1, 4, 6, 5, 2, 3, 7, 0], Cost: 5
# Neighbour: [1, 4, 0, 5, 2, 3, 6, 7], Cost: 5
# Neighbour: [1, 4, 7, 2, 5, 3, 6, 0], Cost: 3
# Neighbour: [1, 4, 7, 3, 2, 5, 6, 0], Cost: 4
# Neighbour: [1, 4, 7, 6, 2, 3, 5, 0], Cost: 3
# Neighbour: [1, 4, 7, 0, 2, 3, 6, 5], Cost: 4
# Neighbour: [1, 4, 7, 5, 3, 2, 6, 0], Cost: 3
# Neighbour: [1, 4, 7, 5, 6, 3, 2, 0], Cost: 4
# Neighbour: [1, 4, 7, 5, 0, 3, 6, 2], Cost: 2
# Neighbour: [1, 4, 7, 5, 2, 6, 3, 0], Cost: 2
# Neighbour: [1, 4, 7, 5, 2, 0, 6, 3], Cost: 1
# Neighbour: [1, 4, 7, 5, 2, 3, 0, 6], Cost: 3
#
# Iteration 2
# Current State: [1, 4, 7, 5, 2, 0, 6, 3], Cost: 1
# Neighbour: [4, 1, 7, 5, 2, 0, 6, 3], Cost: 1
# Neighbour: [7, 4, 1, 5, 2, 0, 6, 3], Cost: 1
# Neighbour: [5, 4, 7, 1, 2, 0, 6, 3], Cost: 5
# Neighbour: [2, 4, 7, 5, 1, 0, 6, 3], Cost: 4
# Neighbour: [0, 4, 7, 5, 2, 1, 6, 3], Cost: 3
# Neighbour: [6, 4, 7, 5, 2, 0, 1, 3], Cost: 3
# Neighbour: [3, 4, 7, 5, 2, 0, 6, 1], Cost: 3
# Neighbour: [1, 7, 4, 5, 2, 0, 6, 3], Cost: 3
# Neighbour: [1, 5, 7, 4, 2, 0, 6, 3], Cost: 2
# Neighbour: [1, 2, 7, 5, 4, 0, 6, 3], Cost: 3
# Neighbour: [1, 0, 7, 5, 2, 4, 6, 3], Cost: 3
# Neighbour: [1, 6, 7, 5, 2, 0, 4, 3], Cost: 3
# Neighbour: [1, 3, 7, 5, 2, 0, 6, 4], Cost: 1
# Neighbour: [1, 4, 5, 7, 2, 0, 6, 3], Cost: 3
# Neighbour: [1, 4, 2, 5, 7, 0, 6, 3], Cost: 3
# Neighbour: [1, 4, 0, 5, 2, 7, 6, 3], Cost: 3
# Neighbour: [1, 4, 6, 5, 2, 0, 7, 3], Cost: 3
# Neighbour: [1, 4, 3, 5, 2, 0, 6, 7], Cost: 5
# Neighbour: [1, 4, 7, 2, 5, 0, 6, 3], Cost: 5
# Neighbour: [1, 4, 7, 0, 2, 5, 6, 3], Cost: 2
# Neighbour: [1, 4, 7, 6, 2, 0, 5, 3], Cost: 3
# Neighbour: [1, 4, 7, 3, 2, 0, 6, 5], Cost: 5
# Neighbour: [1, 4, 7, 5, 0, 2, 6, 3], Cost: 1
# Neighbour: [1, 4, 7, 5, 6, 0, 2, 3], Cost: 5
# Neighbour: [1, 4, 7, 5, 3, 0, 6, 2], Cost: 3
# Neighbour: [1, 4, 7, 5, 2, 6, 0, 3], Cost: 2
# Neighbour: [1, 4, 7, 5, 2, 3, 6, 0], Cost: 2
# Neighbour: [1, 4, 7, 5, 2, 0, 3, 6], Cost: 2
#
# Final Results
# Initial State: [0, 4, 7, 5, 2, 3, 6, 1]
# Final State (Solution): [1, 4, 7, 5, 2, 0, 6, 3]
# Final Cost (Attacking Pairs): 1
# Local optimum reached, but no solution.
